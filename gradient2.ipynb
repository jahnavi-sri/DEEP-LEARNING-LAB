# %%
import tensorflow as tf
import os
import matplotlib.pyplot as plt
os.environ['TF_CPP_MIN_LOG_LEVEL'] ='2'

# %%
# Create needed objects
sgd = tf.keras.optimizers.SGD(learning_rate=0.1, momentum=0.9)
var = tf.Variable(0.5)
cost = lambda: 2+ var ** 6

# %%
x=[]
y=[]

# %%
for _ in range(10):
    sgd.minimize(cost, var_list=[var])
    #print(var.numpy())
    #print(cost().numpy())
    x.append(var.numpy())
    y.append(cost().numpy())

# %%
print(y)
plt.plot(x,marker='o',markerfacecolor='red',color='black')
plt.title('Gradient Descent Function')
plt.xlabel('Iteration')
plt.ylabel('Value of the parameter')
plt.show()
plt.plot(y)
plt.show()
# Out:
# [2.012423, 2.0081813, 2.004669, 2.0024004, 2.0011432, 2.000513, 2.0002189, 2.0000887, 2.000034, 2.0000124]
